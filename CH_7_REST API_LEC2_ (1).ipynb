# %% [markdown]
# # Rest API

# %%
# JSON PLACEHOLDER

# %%
import requests,json
import pandas as pd
url='https://jsonplaceholder.typicode.com/posts/1'
response=requests.get(url)
print(response)#object
#200=ok
#404=not found
# 201=Sucessfull 
print(response.status_code)
print(response.text)
print(type(response.text))
print(type(response))
data=response.json()
print(data)
print(type(data))
userid=data['userId']
title=data['id']
body=data['body']
print("USERID ",userid)
formated=json.dumps(data,indent=4)
print(formated)
# Out:
# <Response [200]>
# 200
# {
#   "userId": 1,
#   "id": 1,
#   "title": "sunt aut facere repellat provident occaecati excepturi optio reprehenderit",
#   "body": "quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto"
# }
# <class 'str'>
# <class 'requests.models.Response'>
# {'userId': 1, 'id': 1, 'title': 'sunt aut facere repellat provident occaecati excepturi optio reprehenderit', 'body': 'quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto'}
# <class 'dict'>
# USERID  1
# {
#     "userId": 1,
#     "id": 1,
#     "title": "sunt aut facere repellat provident occaecati excepturi optio reprehenderit",
# ...

# %%
url='https://jsonplaceholder.typicode.com/posts'
response=requests.get(url)
posts=response.json()
print(type(posts))
print(len(posts))
print('='*50)
print('='*50)
print('='*50)



for post in posts[0:5]:
    print(post['id'])
    print(post['title'])
    print('='*50)
# Out:
# <class 'list'>
# 100
# ...
# 1
# sunt aut facere repellat provident occaecati excepturi optio reprehenderit
# ...
# 2
# qui est esse
# ...
# 3
# ea molestias quasi exercitationem repellat qui ipsa sit aut
# ...
# 4
# eum et est occaecati
# ...
# 5
# nesciunt quas odio
# ...

# %% [markdown]
# # send Quary Paramiter

# %%
param={'userId':1}
url='https://jsonplaceholder.typicode.com/posts'
response=requests.get(url,params=param)
filter_post=response.json()
print(len(filter_post))
print(json.dumps(filter_post,indent=5))
# Out:
# 10
# [
#      {
#           "userId": 1,
#           "id": 1,
#           "title": "sunt aut facere repellat provident occaecati excepturi optio reprehenderit",
#           "body": "quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto"
#      },
#      {
#           "userId": 1,
#           "id": 2,
#           "title": "qui est esse",
#           "body": "est rerum tempore vitae\nsequi sint nihil reprehenderit dolor beatae ea dolores neque\nfugiat blanditiis voluptate porro vel nihil molestiae ut reiciendis\nqui aperiam non debitis possimus qui neque nisi nulla"
#      },
#      {
#           "userId": 1,
#           "id": 3,
#           "title": "ea molestias quasi exercitationem repellat qui ipsa sit aut",
# ...

# %% [markdown]
# # send Custom Headers

# %%
headers={'user-Agent':'Mozilla/5.0','Accept':'application/json'}
reponse=requests.get(url,headers=headers)

print(response.status_code)
# Out:
# 200

# %% [markdown]
# # custom method

# %%
# 1. send post requests
url='https://jsonplaceholder.typicode.com/posts'
new_post={'title':'ljiet','body':'this is collage','userId':1}
response=requests.post(url,json=new_post)
print(response.status_code)
print(response.json()) # actual webpage per dekhashe nahi
# Out:
# 201
# {'title': 'ljiet', 'body': 'this is collage', 'userId': 1, 'id': 101}

# %%
# 2. send put requests (update karva mate use thay...)(post na all parameter change karva pade)
url='https://jsonplaceholder.typicode.com/posts/1'
updated_post={'id':1,'title':'updated_title','body':'updated_body','userId':1} # first data ne update karva mate /1 lakhvanu
response=requests.put(url,json=updated_post)
print(response.status_code)
print(response.json())
# Out:
# 200
# {'id': 1, 'title': 'updated_title', 'body': 'updated_body', 'userId': 1}

# %%
#3.send patch requests (koi post na koi 1 parameter change kari shakay)
url='https://jsonplaceholder.typicode.com/posts/1'
patch_data={'title':'LJIET'}
response=requests.patch(url,json=patch_data)
print(response.status_code)
print(response.json())
# Out:
# 200
# {'userId': 1, 'id': 1, 'title': 'LJIET', 'body': 'quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto'}

# %%
# 4. send Delete requests
url='https://jsonplaceholder.typicode.com/posts/1'
delete=requests.delete(url)
print(delete.status_code)
# Out:
# 200

# %%
# 5. view response header
response=requests.get(url)
print(response.headers)
# Out:
# {'Date': 'Tue, 26 May 2026 04:31:34 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'access-control-allow-credentials': 'true', 'Cache-Control': 'max-age=43200', 'etag': 'W/"124-yiKdLzqO5gfBrJFrcdJ8Yq0LGnU"', 'expires': '-1', 'nel': '{"report_to":"heroku-nel","response_headers":["Via"],"max_age":3600,"success_fraction":0.01,"failure_fraction":0.1}', 'pragma': 'no-cache', 'report-to': '{"group":"heroku-nel","endpoints":[{"url":"https://nel.heroku.com/reports?s=QglcSgAbDGSgTVeC%2FTtt2BgLQcIUu2Sziv5yPbSe4iM%3D\\u0026sid=e11707d5-02a7-43ef-b45e-2cf4d2036f7d\\u0026ts=1772037115"}],"max_age":3600}', 'reporting-endpoints': 'heroku-nel="https://nel.heroku.com/reports?s=QglcSgAbDGSgTVeC%2FTtt2BgLQcIUu2Sziv5yPbSe4iM%3D&sid=e11707d5-02a7-43ef-b45e-2cf4d2036f7d&ts=1772037115"', 'Server': 'cloudflare', 'vary': 'Origin, Accept-Encoding', 'via': '2.0 heroku-router', 'x-content-type-options': 'nosniff', 'x-powered-by': 'Express', '
# ...

# %%
print(response.headers['Content-Type'])
# Out:
# application/json; charset=utf-8

# %% [markdown]
# # download image using Binary Content

# %%
url='https://picsum.photos/200'
response=requests.get(url)
with open('random_image.jpg','wb') as f:
    f.write(response.content)

# %% [markdown]
# # save json data to file

# %%
url='https://jsonplaceholder.typicode.com/posts/1'
response=requests.get(url)
data=response.json()
with open('post1.json','w')as f:
    json.dump(data,f,indent=4)

# %% [markdown]
# # read json data from file

# %%
with open('post1.json','r')as f:
    loaded_data=json.load(f)
    print(loaded_data)
# Out:
# {'userId': 1, 'id': 1, 'title': 'sunt aut facere repellat provident occaecati excepturi optio reprehenderit', 'body': 'quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto'}

# %% [markdown]
# # conver api response to dataframe

# %%
url='https://jsonplaceholder.typicode.com/posts'
response=requests.get(url)
post=response.json()
df=pd.DataFrame(post)
df.head()
# print(df.isna().sum())
# Out:
#    userId  id                                              title  \
# 0       1   1  sunt aut facere repellat provident occaecati e...
# 1       1   2                                       qui est esse
# 2       1   3  ea molestias quasi exercitationem repellat qui...
# 3       1   4                               eum et est occaecati
# 4       1   5                                 nesciunt quas odio
#
#                                                 body
# 0  quia et suscipit\nsuscipit recusandae consequu...
# 1  est rerum tempore vitae\nsequi sint nihil repr...
# 2  et iusto sed quo iure\nvoluptatem occaecati om...
# 3  ullam et saepe reiciendis voluptatem adipisci\...
# 4  repudiandae veniam quaerat sunt sed\nalias aut...

# %% [markdown]
# # conver json String to python object

# %%
json_string='{"name":"alice","age":25}'
python_data=json.loads(json_string)
print(python_data)
print(type(python_data))
# Out:
# {'name': 'alice', 'age': 25}
# <class 'dict'>

# %%
# convert  pyhon object into json string 
person={"name":"alice","age":25}
json_output=json.dumps(person,indent=4)
print(json_output)
# Out:
# {
#     "name": "alice",
#     "age": 25
# }

# %%
# 200=ok
# 201=created
# 400=bad requests
# 401=unauthorized
# 403=forbidden
# 404=not found
# 500=server error

# %% [markdown]
# # Token(Authorization)

# %%
import requests
url='https://jsonplaceholder.typicode.com/posts'
token='my_secret_token'
header={'Authorization':token}
response=requests.get(url,headers=headers)
print(response.status_code)
# Out:
# 200

# %% [markdown]
# # Pagination

# %%
import requests
url='https://jsonplaceholder.typicode.com/posts'
param={'_page':1,"_limit":5}
response=requests.get(url,params=param)
print(response.status_code)
data=response.json()
print('POs')
# Out:
# 200
